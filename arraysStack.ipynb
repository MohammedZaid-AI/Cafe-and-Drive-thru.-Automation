# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammedZaid-AI/Cafe-and-Drive-thru.-Automation/blob/main/arraysStack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Stack():

  def __init__(self,size):
    self.size=size
    self.stack=[None]* self.size
    self.top=-1

  def push(self,value):
    if self.top==self.size-1:
      return ("Overflow")
    else:
      self.top+=1
      self.stack[self.top]=

  def pop(self):
    if self.top==-1:
      return "underflow"
    else:
